# %% [markdown]
# ##Review Classification  Part -1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_yelp = pd.read_csv('/content/yelp_labelled.txt', sep='\t', header=None)

# %%
data_yelp.head()

# review and sentiment
# 0-Negative, 1-Positive for positive review
# Out:
#                                                    0  1
# 0                           Wow... Loved this place.  1
# 1                                 Crust is not good.  0
# 2          Not tasty and the texture was just nasty.  0
# 3  Stopped by during the late May bank holiday of...  1
# 4  The selection on the menu was great and so wer...  1

# %%
## Assign column names
columan_name = ['Review', 'Sentiment']
data_yelp.columns = columan_name

# %%
data_yelp.head()
# Out:
#                                               Review  Sentiment
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
data_yelp.shape
##1000 rows (reviews), 2 columns (Sentiments)
# Out:
# (1000, 2)

# %%
data_amazon = pd.read_csv('/content/amazon_cells_labelled.txt', sep='\t', header=None)
data_amazon.head()
#review and sentiment
# 0-Negative, 1-Positive for positive review
# Out:
#                                                    0  1
# 0  So there is no way for me to plug it in here i...  0
# 1                        Good case, Excellent value.  1
# 2                             Great for the jawbone.  1
# 3  Tied to charger for conversations lasting more...  0
# 4                                  The mic is great.  1

# %%
data_amazon.columns = columan_name

# %%
data_amazon.head()
# Out:
#                                               Review  Sentiment
# 0  So there is no way for me to plug it in here i...          0
# 1                        Good case, Excellent value.          1
# 2                             Great for the jawbone.          1
# 3  Tied to charger for conversations lasting more...          0
# 4                                  The mic is great.          1

# %%
data_amazon.shape
# Out:
# (1000, 2)

# %%
data_imdb = pd.read_csv('/content/imdb_labelled.txt', sep='\t', header=None)
data_imdb.head()

#review and sentiment
# 0-Negative, 1-Positive for positive review
# Out:
#                                                    0  1
# 0  A very, very, very slow-moving, aimless movie ...  0
# 1  Not sure who was more lost - the flat characte...  0
# 2  Attempting artiness with black & white and cle...  0
# 3       Very little music or anything to speak of.    0
# 4  The best scene in the movie was when Gerardo i...  1

# %%
data_imdb.columns = columan_name

# %%
data_imdb.head()
# Out:
#                                               Review  Sentiment
# 0  A very, very, very slow-moving, aimless movie ...          0
# 1  Not sure who was more lost - the flat characte...          0
# 2  Attempting artiness with black & white and cle...          0
# 3       Very little music or anything to speak of.            0
# 4  The best scene in the movie was when Gerardo i...          1

# %%
data_imdb.shape
# Out:
# (748, 2)

# %%
##Append all the data in single dataframe

# %%
data = data_yelp.append([data_amazon, data_imdb],ignore_index=True)

# data= data[:2000]

# %%
data.shape
# Out:
# (2748, 2)

# %%
data.head()
# Out:
#                                               Review  Sentiment
# 0                           Wow... Loved this place.          1
# 1                                 Crust is not good.          0
# 2          Not tasty and the texture was just nasty.          0
# 3  Stopped by during the late May bank holiday of...          1
# 4  The selection on the menu was great and so wer...          1

# %%
# check distribution of sentiments

# %%
data['Sentiment'].value_counts()
# 1346 positive reviews
# 1362 Negative reviews
# Out:
# 1    1386
# 0    1362
# Name: Sentiment, dtype: int64

# %%
# check for null values
data.isnull().sum()

# no null values in the data
# Out:
# Review       0
# Sentiment    0
# dtype: int64

# %%
x = data['Review']
y = data['Sentiment']

# %% [markdown]
# ##Data Cleaning

# %%
## here we will remove stopwords, punctuations
## as well as we will apply lematization

# %% [markdown]
# ###Create a function toclean the data

# %%
import string

# %%
punct = string.punctuation

# %%
punct
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
stopwords = list(STOP_WORDS) # list of stopwords

# %%
stopwords
# Out:
# ['herself',
#  'two',
#  'after',
#  'thru',
#  'was',
#  'we',
#  'does',
#  'four',
#  'her',
#  'must',
#  'whither',
#  'since',
#  'where',
#  'mine',
#  'also',
#  'more',
#  'keep',
#  'me',
#  'until',
#  'hereafter',
#  'whatever',
#  'eight',
#  'most',
#  'off',
#  'about',
#  '‘d',
#  'across',
#  'used',
#  'whoever',
#  'perhaps',
#  'them',
#  'therein',
#  'latterly',
#  'fifteen',
#  'why',
#  'doing',
#  'be',
#  'became',
#  'between',
#  'seeming',
#  'below',
#  'then',
#  'least',
#  'before',
#  'together',
#  'really',
#  '‘ve',
#  'now',
#  'will',
#  'front',
#  'down',
#  'my',
#  "'ve",
#  'often',
#  'neither',
#  'others',
#  'throughout',
#  'rather',
#  'would',
#  'else',
#  'even',
#  'every',
#  'show',
#  'they',
#  'without',
#  'become',
#  'nor',
#  "'ll",
#  'has',
#  'part',
#  'there',
#  'back',
#  'from',
#  'this',
#  'various',
#  'is',
#  'twelve',
#  'three',
#  'him',
#  'none',
#  'put',
#  'own',
#  'another',
#  'ourselves',
#  'anyhow',
#  'next',
#  'might',
#  'had',
#  'do',
#  'ours',
#  'nothing',
#  'myself',
#  'ca',
#  '’s',
#  'hereupon',
#  'nine',
#  'ten',
#  'in',
#  'yourself',
#  'therefore',
#  'besides',
#  'beside',
#  'but',
#  'namely',
#  'she',
#  'our',
#  'third',
#  'what',
#  'towards',
#  'mostly',
#  'not',
#  'well',
#  '’d',
#  'afterwards',
#  'of',
#  'once',
#  'these',
#  'go',
#  'last',
#  'bottom',
#  'their',
#  'twenty',
#  'because',
#  'regarding',
#  'elsewhere',
#  'yourselves',
#  'he',
#  'up',
#  'whose',
#  "'m",
#  'full',
#  'side',
#  'whereupon',
#  'thereupon',
#  'among',
#  'six',
#  'everywhere',
#  'anywhere',
#  'his',
#  'otherwise',
#  'beforehand',
#  'still',
#  'i',
#  'many',
#  'ever',
#  'too',
#  'n’t',
#  'when',
#  'further',
#  'both',
#  'through',
#  'only',
#  'you',
#  'or',
#  'under',
#  'very',
#  'due',
#  'nobody',
#  'seem',
#  'anyone',
#  'nowhere',
#  'have',
#  'thereafter',
#  'its',
#  'done',
#  'name',
#  'yours',
#  'toward',
#  'much',
#  'anyway',
#  'wherein',
#  'thus',
#  '’m',
#  'can',
#  'how',
#  'n‘t',
#  'themselves',
#  'into',
#  'call',
#  '’re',
#  'either',
#  'unless',
#  'see',
#  '‘s',
#  'may',
#  'and',
#  'for',
#  'over',
#  'hence',
#  'wherever',
#  'should',
#  'serious',
#  're',
#  'whereafter',
#  'on',
#  'that',
#  'anything',
#  'whenever',
#  '’ll',
#  'take',
#  'becomes',
#  'those',
#  'five',
#  'somehow',
#  'top',
#  'did',
#  'make',
#  'quite',
#  'herein',
#  'almost',
#  'same',
#  'eleven',
#  'us',
#  'though',
#  'seemed',
#  'such',
#  'moreover',
#  'formerly',
#  'several',
#  'again',
#  'meanwhile',
#  'while',
#  'thereby',
#  'sometime',
#  'empty',
#  'himself',
#  'along',
#  'indeed',
#  'everyone',
#  'behind',
#  'to',
#  'just',
#  'never',
#  'were',
#  'thence',
#  'noone',
#  'something',
#  'am',
#  "'d",
#  'already',
#  'against',
#  'somewhere',
#  'as',
#  'by',
#  'are',
#  'nevertheless',
#  'could',
#  'forty',
#  '‘m',
#  'an',
#  'becoming',
#  'whence',
#  'other',
#  'hundred',
#  'one',
#  'although',
#  '’ve',
#  'give',
#  'using',
#  'the',
#  'been',
#  'it',
#  'made',
#  'hers',
#  'above',
#  'less',
#  'hereby',
#  'whom',
#  'few',
#  'each',
#  'some',
#  'than',
#  'itself',
#  'amount',
#  'if',
#  'per',
#  'everything',
#  'within',
#  'out',
#  'yet',
#  'whole',
#  'which',
#  '‘ll',
#  'upon',
#  'during',
#  'move',
#  'sixty',
#  'beyond',
#  'whereas',
#  'onto',
#  'who',
#  "'s",
#  'please',
#  'latter',
#  'except',
#  'cannot',
#  'someone',
#  'former',
#  'a',
#  'get',
#  '‘re',
#  'all',
#  'enough',
#  'being',
#  "'re",
#  'so',
#  "n't",
#  'whereby',
#  'say',
#  'sometimes',
#  'first',
#  'at',
#  'alone',
#  'always',
#  'whether',
#  'no',
#  'your',
#  'however',
#  'with',
#  'via',
#  'amongst',
#  'seems',
#  'here',
#  'fifty',
#  'around',
#  'any']

# %%
#creating a function for data cleaning

# %%
import spacy 

nlp = spacy.load('en_core_web_sm')

def text_data_cleaning(sentence):
  doc = nlp(sentence)

  tokens = [] # list of tokens
  for token in doc:
    if token.lemma_ != "-PRON-":
      temp = token.lemma_.lower().strip()
    else:
      temp = token.lower_
    tokens.append(temp)
  
  cleaned_tokens = []
  for token in tokens:
    if token not in stopwords and token not in punct:
      cleaned_tokens.append(token)
  return cleaned_tokens

# %%
## if root form of that word is not pronoun then it is goingto convert that into lower form
# and if that word is a poper noun, then we aer directly taking lower form, because there is no lemma

# %%
text_data_cleaning("Hello all, It's a beautiful day outside there!")
#stopwords and punctuations removed
# Out:
# ['hello', 'beautiful', 'day', 'outside']

# %% [markdown]
# ### Vektorization Feature Engineering(TF-IDF)

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

# %%
tfidf = TfidfVectorizer(tokenizer=text_data_cleaning)
#tokenizer=text_data_cleaning, tokenization will bedone according to this function

# %%
classifier = LinearSVC()

# %% [markdown]
# ##Train the model

# %% [markdown]
# ### Splitting the dataset into the Train and Test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2 , random_state= 0 )

# %%
x_train.shape, x_test.shape
# 2198 samples in training dataset and 550 in test dataset
# Out:
# ((2198,), (550,))

# %%
x_train.head()
# Out:
# 2572    An Italian reviewer called this "a small, grea...
# 526                          And it was way to expensive.
# 1509    As an earlier review noted, plug in this charg...
# 144     Nice blanket of moz over top but i feel like t...
# 2483    The film gives meaning to the phrase, "Never i...
# Name: Review, dtype: object

# %% [markdown]
# ###Fit thex_train any_train

# %%
clf = Pipeline([('tfidf',tfidf), ('clf', classifier)])
# it will first do vectorization and then it will do classification

# %%
clf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(tokenizer=<function text_data_cleaning at 0x7fb6f4956820>)),
#                 ('clf', LinearSVC())])

# %% [markdown]
# ## 4) Predict the Test set results

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
y_pred = clf.predict(x_test)

# %%
# confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[200,  79],
#        [ 51, 220]])

# %%
# classification_report
print(classification_report(y_test, y_pred))
# we are getting almost 77% accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.75       279
#            1       0.74      0.81      0.77       271
#
#     accuracy                           0.76       550
#    macro avg       0.77      0.76      0.76       550
# weighted avg       0.77      0.76      0.76       550

# %%
accuracy_score(y_test, y_pred)
# 76% accuracy
# Out:
# 0.7636363636363637

# %%
clf.predict(["Wow, I am learning Natural Language Processing in fun fashion!"])
# output is 1, that means review is positive
# Out:
# array([1])

# %%
clf.predict(["It's hard to learn new things!"])
# output is 0, that means review is Negative
# Out:
# array([0])
